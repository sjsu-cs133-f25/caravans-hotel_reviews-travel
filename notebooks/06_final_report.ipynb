# %% [markdown]
# # Sprint 6: Final Report

# %% [markdown]
# ## Colab Setup:

# %%
import numpy as np
import pandas as pd
import ast
import textwrap
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import folium

import kagglehub
path = kagglehub.dataset_download("jiashenliu/515k-hotel-reviews-data-in-europe")
print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the '515k-hotel-reviews-data-in-europe' dataset.
# Path to dataset files: /kaggle/input/515k-hotel-reviews-data-in-europe

# %%
df = pd.read_csv(f"{path}/Hotel_Reviews.csv")

# %% [markdown]
# ## A: Data Card (updated)
#
# **Source & Link:** 515K Hotel Reviews Data in Europe (Kaggle) - https://www.kaggle.com/datasets/jiashenliu/515k-hotel-reviews-data-in-europe/data
#
# **Shape:** 515,738 rows x 18 columns
#
# **Time Coverage:** August 4, 2015 - August 3, 2017
#
#
#
# ##Column Dictionary:
# - **Hotel_Address:** address of the hotel
# - **Additional_Number_of_Scoring:** number of scores given without an accompanying review
# - **Review_Date:** date when the review was posted
# - **Average_Score:** average score of the hotel
# - **Hotel_Name:** name of the hotel
# - **Reviewer_Nationality:** nationality of the reviewer
# - **Negative_Review:** text content of negative review, if the reviewer did not give a negative review it says "No Negative"
# - **Review_Total_Negative_Word_Counts:** number of words in negative review
# - **Total_Number_of_Reviews:** the total number of reviews
# - **Positive_Review:** text content of positve reviews, if the reviewer did not give a positive review it says "No Positive"
# - **Review_Total_Positive_Word_Counts:** number of words in positive review
# - **Total_Number_of_Reviews_Reviewer_Has_Given:** number of reviews given by the reviewer
# - **Reviewer_Score:** score given by the reviewer
# - **Tags:** tags given to hotel by the reviewer
# - **days_since_review:** days between date of review and the date it was scraped
# - **lat:** latitude of hotel
# - **lng:** longitude of hotel
#
# New Columns:
# - **Hotel_Country:** country of the reviewed hotel
# - **Year:** year when review was posted
# - **Review_Total_Word_Counts:** the total word-counts derived from adding positive review word-counts and negative review word-counts
#
#
#
#
# **Key ID Columns:** 'Hotel_Name', 'Review_Date'
#
#
# ##Missingness Snapshot:
# N/A
#
#
# ##Quirks:
# - **Hotel_Country** only includes 6 countries: Netherlands, UK, France, Spain, Italy, Austria

# %% [markdown]
# ## B: Transformation

# %%
df['Hotel_Address'] = df['Hotel_Address'].str.replace('United Kingdom', 'UK')
hotel_country = df['Hotel_Address'].str.split(' ').str[-1]
df['Hotel_Address'] = df.apply(lambda row: ' '.join(row['Hotel_Address'].split(' ')[:-1]), axis=1)

df['Hotel_Country'] = hotel_country

# %%
colors = {
    'Netherlands':'red',
    'UK':'grey',
    'France':'blue',
    'Spain':'yellow',
    'Italy':'green',
    'Austria':'orange'
}

# %%
countries = df['Hotel_Country'].unique()
top_hotels = {}
for country in countries:
  popular_hotel = df[df['Hotel_Country']==country].groupby('Hotel_Name').Reviewer_Score.mean().idxmax();
  popular_hotel_reviews = df[df['Hotel_Name']==popular_hotel].copy()
  top_hotels[country] = popular_hotel_reviews
  # Turn Tags column from string representation of list to string with comma-separated tags
  top_hotels[country]['Tags'] = top_hotels[country].apply(lambda row: ', '.join(map(lambda x: x.strip(), ast.literal_eval(row['Tags']))), axis=1)
  # Add line wrapping to Tags (for hover text)
  top_hotels[country]['Tags'] = top_hotels[country].apply(lambda row: '<br>'.join(textwrap.wrap(row['Tags'], width=40)), axis=1)

'''
for a in top_hotels:
  print(a, top_hotels[a]['Hotel_Name'].unique(), top_hotels[a].Reviewer_Score.count())
'''
# Out:
# "\nfor a in top_hotels:\n  print(a, top_hotels[a]['Hotel_Name'].unique(), top_hotels[a].Reviewer_Score.count())\n"

# %% [markdown]
# ## C: Visuals

# %%
hotels = df.groupby(['lat', 'lng', 'Hotel_Name', 'Hotel_Country'])

m = folium.Map(location=[54.526, 15.255], zoom_start=4)
for (lat, lng, hotel_name, hotel_country), group in hotels:
    counts = group['Reviewer_Nationality'].value_counts().head(5)
    popup_text = "<br>".join([f"{c}: {v}" for c, v in counts.items()])
    marker_color = colors.get(hotel_country)
    folium.CircleMarker(
        location=[lat, lng],
        radius=7,
        color=marker_color,
        fill=True,
        fill_opacity=0.8,
        tooltip=popup_text
    ).add_to(m)
map_title = "Number of Reviews for Hotels by Reviewer Nationality"
title_html = f'<h3 align="center" style="font-size:16px"><b>{map_title}</b></h3>'
m.get_root().html.add_child(folium.Element(title_html))
m.save('map-with-title.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c73cd8799b6b06161cabbeec8a6ef0f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Number of Reviews for Hotels by Reviewer Nationality&lt;/b&gt;&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c73cd8799b6b06161cabbeec8a6ef0f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c73cd8799b6b06161cabbeec8a6ef0f = L.map(
#                 &quot;map_7c73cd8799b6b06161cabbeec8a6ef0f&quot;,
#                 {
#                     center: [54.526, 15.255],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_597362a75a9ac73c374c27623aa0b23b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_597362a75a9ac73c374c27623aa0b23b.addTo(map_7c73cd8799b6b06161cabbeec8a6ef0f);
#
#
#             var circle_marker_3ec6125469c840ddeff919f8866e86ef = L.circleMarker(
#                 [41.3283758, 2.1129638],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7c73cd8799b6b06161cabbeec8a6ef0f);
#
#
#             circle_marker_3ec6125469c840ddeff919f8866e86ef.bindTooltip(
#                 `&lt;div&gt;
#                       United States of America : 131&lt;br&gt; United Kingdom : 109&lt;br&gt; Spain : 49&lt;br&gt; Canada : 40&lt;br&gt; Australia : 19
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_e17eb43e1c38de6ac41b3badfa92de19 = L.circleMarker(
#                 [41.368437, 2.1901534],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7c73cd8799b6b06161cabbeec8a6ef0f);
#
#
#             circle_marker_e17eb43e1c38de6ac41b3badfa92de19.bindTooltip(
#                 `&lt;div&gt;
#                       United Kingdom : 266&lt;br&gt; Saudi Arabia : 35&lt;br&gt; United States of America : 29&lt;br&gt; United Arab Emirates : 27&lt;br&gt; Spain : 19
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_e23971901dd0ebdefe7bad22eea21f55 = L.circleMarker(
#                 [41.3703041, 2.17141],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7c73cd8799b6b06161cabbeec8a6ef0f);
#
#
#             circle_marker_e23971901dd0ebdefe7bad22eea21f55.bindTooltip(
#                 `&lt;div&gt;
#                       United Kingdom : 90&lt;br&gt; Saudi Arabia : 17&lt;br&gt; United States of America : 12&lt;br&gt; Switzerland : 11&lt;br&gt; Spain : 11
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_8aec7ed6aa134a4f00be14f33154a8d4 = L.circleMarker(
#                 [41.371308, 2.181698],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7c73

# %%
fig = go.Figure()

for country, hotel_reviews in top_hotels.items():
  # Create a Plotly Express figure for each country
  px_fig = px.strip(
    hotel_reviews,
    x='Hotel_Name',
    y='Reviewer_Score',
    color='Hotel_Country',
    color_discrete_map=colors,
    custom_data=['Tags'],
  )
  px_fig.update_traces(
      hovertemplate =
                f'<b>{country}</b></br>' +
                '<b>%{x}</b><br><br>' +
                'Tags: %{customdata[0]}' +
                '<extra></extra>',
  )
  # print(px_fig.data[0])
  # print(px_fig.data[0].hovertemplate)

  # Add all traces from the Plotly Express figure to the main go.Figure()
  for trace in px_fig.data:
    fig.add_trace(trace)

fig.update_layout(
    title='Review Scores for Top Hotel by Country',
    xaxis_title='Hotel Name',
    yaxis_title='Reviewer Score',
    width=1000,
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4f9b03aa-4956-408f-8eb6-e6cfa9d3eaeb" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f9b03aa-4956-408f-8eb6-e6cfa9d3eaeb")) {                    Plotly.newPlot(                        "4f9b03aa-4956-408f-8eb6-e6cfa9d3eaeb",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[["Leisure trip, Couple, King Deluxe Room,\u003cbr\u003eStayed 1 night, Submitted from a mobile\u003cbr\u003edevice"],["Leisure trip, Solo traveler, King Grand\u003cbr\u003ePremier Room, Stayed 3 nights"],["Leisure trip, Family with young\u003cbr\u003echildren, King Junior Suite with View,\u003cbr\u003eStayed 7 nights, Submitted from a mobile\u003cbr\u003edevice"],["Leisure trip, Couple, King Junior Suite\u003cbr\u003ewith View, Stayed 3 nights"],["Leisure trip, Family with young\u003cbr\u003echildren, King Grand Premier with Canal\u003cbr\u003eView, Stayed 2 nights"],["Leisure trip, Couple, King Grand Premier\u003cbr\u003eRoom, Stayed 2 nights, Submitted from a\u003cbr\u003emobile device"],["Leisure trip, Group, Queen Deluxe Room,\u003cbr\u003eStayed 2 nights, Submitted from a mobile\u003cbr\u003edevice"],["Leisure trip, Solo traveler, King Deluxe\u003cbr\u003eRoom, Stayed 3 nights, Submitted from a\u003cbr\u003emobile device"],["Leisure trip, Couple, King Loft, Stayed\u003cbr\u003e3 nights"],["Business trip, Couple, King Superior\u003cbr\u003ePlus Room, Stayed 3 nights"],["Leisure trip, Couple, King Superior\u003cbr\u003eRoom, Stayed 1 night"],["Business trip, Solo traveler, King Grand\u003cbr\u003ePremier with Canal View, Stayed 2 nights"],["Leisure trip, Solo traveler, Queen\u003cbr\u003eDeluxe Room, Stayed 1 night"],["Leisure trip, Couple, King Grand Premier\u003cbr\u003eRoom, Stayed 1 night"],["Leisure trip, Couple, King Superior\u003cbr\u003eRoom, Stayed 1 night, Submitted from a\u003cbr\u003emobile device"],["Leisure trip, Solo traveler, King Grand\u003cbr\u003ePremier Room, Stayed 3 nights"],["Business trip, Couple, King Premier\u003cbr\u003eRoom, Stayed 3 nights"],["Leisure trip, Couple, King Grand Premier\u003cbr\u003eRoom, Stayed 5 nights"],["Leisure trip, Couple, King Grand Premier\u003cbr\u003eRoom, Stayed 2 nights"],["Leisure trip, Family with older\u003cbr\u003echildren, Twin Grand Premier with Canal\u003cbr\u003eView, Stayed 3 nights"],["Leisure trip, Family with older\u003cbr\u003echildren, King Grand Premier Room,\u003cbr\u003eStayed 5 nights, Submitted from a mobile\u003cbr\u003edevice"],["Leisure trip, Family with older\u003cbr\u003echildren, King Premier Room, Stayed 2\u003cbr\u003enights"],["Leisure trip, Couple, King Grand Premier\u003cbr\u003ewith Canal View, Stayed 3 nights"],["Leisure trip, Couple, King Grand Premier\u003cbr\u003eRoom, Stayed 4 nights"],["Business trip, Solo traveler, King Grand\u003cbr\u003ePremier Room, Stayed 1 night"],["Leisure trip, Couple, King Junior Suite\u003cbr\u003ewith View, Stayed 2 nights"],["Leisure trip, Couple, King Grand Premier\u003cbr\u003eRoom, Stayed 4 nights, Submitted from a\u003cbr\u003emobile device"],["Leisure trip, Family with young\u003cbr\u003echildren, 2 rooms, Stayed 1 night,\u003cbr\u003eSubmitted from a mobile device"],["Leisure trip, Couple, King Grand Premier\u003cbr\u003ewith Canal View, Stayed 3 nights"],["Leisure trip, Couple, King Deluxe Room,\u003cbr\u003eStayed 1 night"],["Leisure trip, Solo traveler, King Deluxe\u003cbr\u003eRoom, Stayed 1 night, Submitted from a\u003cbr\u003emobile device"],["Leisure trip, Couple, King Grand Premier\u003cbr\u003eRoom, Stayed 2 nights, Submitted from a\u003cbr\u003emobile device"],["Leisure trip, Couple, King Superior Plus\u003cbr\u003eRoom, Stayed 1 night"],["Leisure trip, Family with older\u003cb ...
